# %%
import pandas as pd

# %%
data = pd.read_csv('data/processed_data.csv',index_col='id')
reviews = list(data['tweet'].apply(str))
labels = list(data['label'])

# %%
for sent in reviews:
    sent.split()

# %%
corpus = [word for sent in reviews for word in str(sent).split()]

# %%
word2index = {}
for i,word in enumerate(corpus):
    word2index[word] = i
word2index
# Out:
# {'when': 245233,
#  'father': 244190,
#  'dysfunctional': 2,
#  'selfish': 214172,
#  'drags': 238952,
#  'kids': 239848,
#  'into': 244014,
#  'dysfunction': 194202,
#  '#run': 235279,
#  'thanks': 245060,
#  '#lyft': 194206,
#  'credit': 229345,
#  'cause': 235175,
#  'they': 245090,
#  'offer': 243743,
#  'wheelchair': 64453,
#  'vans': 16,
#  '#disapointed': 17,
#  '#getthanked': 79030,
#  'bihday': 243917,
#  'your': 245227,
#  'majesty': 205876,
#  '#model': 245144,
#  'love': 245149,
#  'take': 244843,
#  'with': 245210,
#  'time': 245243,
#  'factsguide': 240977,
#  'society': 243471,
#  '#motivation': 243184,
#  'huge': 237781,
#  'fare': 161248,
#  'talking': 234357,
#  'before': 244130,
#  'leave': 244746,
#  'chaos': 221455,
#  'disputes': 37,
#  'there': 245085,
#  '#allshowandnogo': 41,
#  'camping': 234512,
#  'tomorrow': 245239,
#  'danny': 242048,
#  'next': 244850,
#  'school': 244230,
#  'year': 245125,
#  'exams': 233800,
#  'think': 244204,
#  'about': 244328,
#  'that': 245245,
#  '#school': 236807,
#  '#exams': 220707,
#  '#hate': 239356,
#  '#imagine': 235373,
#  '#actorslife': 177048,
#  '#revolutionschool': 58,
#  '#girl': 245218,
#  'land': 238820,
#  '#allin': 151180,
#  '#cavs': 210358,
#  '#champions': 229686,
#  '#cleveland': 151184,
#  '#clevelandcavaliers': 66,
#  'welcome': 237589,
#  'here': 245122,
#  '#ireland': 240119,
#  'consumer': 241826,
#  'price': 241827,
#  'index': 241828,
#  'climbed': 190306,
#  'from': 245075,
#  'previous': 240966,
#  '#blog': 243336,
#  '#silver': 243337,
#  '#gold': 243338,
#  '#forex': 243339,
#  '#orlando': 244876,
#  '#standwithorlando': 129322,
#  '#pulseshooting': 193625,
#  '#orlandoshooting': 240659,
#  '#biggerproblems': 85,
#  '#selfish': 129622,
#  '#heabreaking': 239519,
#  '#values': 109581,
#  '#love': 245127,
#  'daddy': 244241,
#  'today': 244933,
#  'days': 244616,
#  '#gettingfed': 93,
#  '#cnn': 242611,
#  'calls': 233159,
#  '#michigan': 155864,
#  'middle': 240810,
#  'build': 231897,
#  'wall': 234191,
#  'chant': 163117,
#  '#tcot': 233861,
#  'comment': 224564,
#  '#australia': 201803,
#  '#opkillingbay': 172229,
#  '#seashepherd': 241544,
#  '#helpcovedolphins': 172231,
#  '#thecove': 172232,
#  'ouch': 222859,
#  'junior': 205316,
#  'angry': 244726,
#  '#got': 204694,
#  '#junior': 114,
#  '#yugyoem': 115,
#  '#omg': 244877,
#  'thankful': 244714,
#  'having': 245198,
#  'paner': 228779,
#  '#thankful': 244716,
#  '#positive': 244717,
#  'retweet': 218779,
#  'agree': 244656,
#  '#friday': 245120,
#  'smiles': 243515,
#  'around': 243122,
#  'user': 240320,
#  '#cookies': 192304,
#  'make': 245105,
#  'people': 245148,
#  'know': 245094,
#  'essential': 222461,
#  'oils': 222462,
#  'made': 244763,
#  'chemicals': 135,
#  '#euro': 244914,
#  'blaming': 202622,
#  'conceded': 139,
#  'goal': 236897,
#  'rooney': 202795,
#  'gave': 239212,
#  'away': 245174,
#  'free': 243740,
#  'kick': 235741,
#  'knowing': 243014,
#  'bale': 147,
#  'them': 245006,
#  'little': 243878,
#  'dude': 229945,
#  '#badday': 160406,
#  '#coneofshame': 154,
#  '#cats': 236540,
#  '#pissed': 188110,
#  '#funny': 244057,
#  '#laughs': 138961,
#  'product': 232911,
#  'happy': 245101,
#  '#wine': 241215,
#  'tool': 222001,
#  '#weekend': 243951,
#  'open': 241122,
#  'drink': 245084,
#  'lumpy': 245175,
#  'says': 243259,
#  'prove': 244955,
#  '#tgif': 244262,
#  '#gamedev': 244263,
#  '#indiedev': 244264,
#  '#indiegamedev': 244265,
#  '#squad': 244994,
#  'beautiful': 244602,
#  'sign': 244730,
#  'vendor': 235856,
#  '#upsideofflorida': 198692,
#  '#shopalyssas': 198693,
#  '#smiles': 243513,
#  '#media': 242618,
#  '#pressconference': 185,
#  '#antalya': 186,
#  '#turkey': 227300,
#  'sunday': 244988,
#  '#throwback': 234323,
#  'great': 244782,
#  'panel': 234356,
#  'mediatization': 193,
#  'public': 233373,
#  'service': 243088,
#  '#ica': 136358,
#  'went': 245209,
#  'nightclub': 229891,
#  'have': 245170,
#  'good': 245211,
#  'night': 244883,
#  'actions': 236694,
#  'means': 244882,
#  'those': 244383,
#  'lost': 244384,
#  'their': 244326,
#  'families': 239318,
#  'forever': 241709,
#  '#rip#orlando': 213,
#  'never': 244871,
#  'chance': 225424,
#  'vote': 244301,
#  'presidential': 240665,
#  'candidate': 200530,
#  'excited': 244134,
#  'this': 245142,
#  'cycle': 225562,
#  'looks': 242273,
#  'different': 242999,
#  '#alohafriday': 203552,
#  '#time': 239755,
#  'does': 244668,
#  '#not': 234454,
#  '#exist': 127626,
#  '#positivevibes': 237557,
#  '#hawaiian': 155652,
#  'fellow': 244771,
#  'nohern': 236546,
#  'ireland': 243191,
#  'sadley': 236,
#  'passed': 245123,
#  'tonight': 244936,
#  'gawa': 240,
#  'singing': 233669,
#  'cheering': 216602,
#  'fire': 242206,
#  'hard': 244389,
#  'monday': 245263,
#  'cloudy': 186687,
#  'weather': 243551,
#  'disabling': 249,
#  'oxygen': 7636,
#  'production': 234977,
#  '#goodnight': 239478,
#  '#badmonday': 254,
#  'unbelievable': 228831,
#  'century': 201593,
#  'need': 244953,
#  'something': 244132,
#  'like': 245256,
#  'again': 243081,
#  '#neverump': 243934,
#  '#xenophobia': 211014,
#  '#taylorswift': 190603,
#  'bull': 245228,
#  'will': 245229,
#  'dominate': 245226,
#  'direct': 245230,
#  'whatever': 245231,
#  'want': 245232,
#  'morning': 245264,
#  '#travelingram': 243906,
#  '#dalat': 277,
#  '#ripinkylife': 137779,
#  'once': 243448,
#  'more': 245151,
#  'only': 244923,
#  'word': 244069,
#  'tells': 223526,
#  '#photoshop': 27800,
#  '#enoughisenough': 188770,
#  '#dontphotoshopeverything': 286,
#  '#wheresallthenaturalphotos': 287,
#  '#cedarpoint': 27490,
#  'waited': 219402,
#  'hours': 242957,
#  'valravn': 291,
#  'line': 243459,
#  'stopped': 216401,
#  'working': 240860,
#  'were': 245017,
#  'close': 241319,
#  'sunshine': 244635,
#  'finally': 245121,
#  'finish': 241258,
#  'book': 241853,
#  'been': 244378,
#  'awhile': 216675,
#  '#bookworm': 181932,
#  '#ontothenextnovel': 309,
#  'being': 245041,
#  'knicks': 311,
#  'easier': 227859,
#  'just': 245203,
#  'playoffs': 194217,
#  'roll': 241650,
#  'life': 245096,
#  'after': 244628,
#  'social': 240980,
#  'networking': 209516,
#  'embrace': 211211,
#  'each': 244792,
#  'shares': 230692,
#  'same': 242918,
#  'snake': 141428,
#  'weekend': 242902,
#  'lovely': 244920,
#  'echeveria': 334,
#  'blooms#flowers': 335,
#  '#grow': 211651,
#  '#gardening': 191648,
#  '#iphonesia': 338,
#  '#bliss': 232363,
#  '#blooms': 198882,
#  '#basilicabotanica': 341,
#  'amazing': 244706,
#  '#affirmation': 244269,
#  '#whenever': 104982,
#  '#something': 104983,
#  'goes': 242527,
#  '#wrong': 191485,
#  'feeling': 244931,
#  'blue': 239734,
#  '#illustration': 228489,
#  'best': 243498,
#  '#abc': 234345,
#  'getting': 243932,
#  'ready': 243894,
#  'remove': 231247,
#  'victums': 365,
#  '#pulseclub': 24844,
#  '#prayfororlando': 243587,
#  '#bihday': 243703,
#  '#nose': 212869,
#  '#job': 204798,
#  '#petunia': 372,
#  'concelebrate': 374,
#  '#albanpilgrimage': 44626,
#  'first': 245242,
#  'scum': 232984,
#  'baggery': 106729,
#  'begin': 240683,
#  'thank': 245272,
#  'super': 241893,
#  'zpamdelacruz': 384,
#  '#wedding#': 385,
#  'dolores': 386,
#  'capas': 387,
#  'tarlac': 388,
#  'scourge': 389,
#  'playing': 244542,
#  'baroque': 392,
#  'pieces': 229559,
#  'piano': 235479,
#  'beyond': 243192,
#  'belief': 162548,
#  'lets': 244774,
#  'fight': 243991,
#  'against': 241971,
#  '#peace': 244755,
#  'rayos': 404,
#  '#video': 240229,
#  '#fathers': 244279,
#  '#day': 245162,
#  '#rayos': 408,
#  '#world': 243708,
#  '#hotvideo': 108227,
#  '#videos': 192504,
#  'ascot': 199121,
#  'times': 242140,
#  'babe': 209156,
#  '#ascot': 220769,
#  '#fashion': 241952,
#  '#monochrome': 171094,
#  '#style': 244359,
#  '#instahappyday': 171096,
#  '#selfie': 244824,
#  '#yolo': 226712,
#  '#xoxo': 239633,
#  '#like': 241010,
#  'work': 245265,
#  'conference': 243404,
#  'right': 243224,
#  'mindset': 243225,
#  'leads': 243226,
#  'culture': 243227,
#  'development': 244181,
#  'organizations': 243229,
#  '#work': 243293,
#  '#mindset': 244108,
#  'christina': 226886,
#  'grimmie': 226887,
#  'last': 244820,
#  'performance': 239244,
#  'shot': 243968,
#  '#christinarip': 447,
#  '#voice': 226238,
#  '#christinagrimmie': 222087,
#  'dance': 235395,
#  '#roar': 3083,
#  '#preschoolers': 453,
#  '#students': 194370,
#  '#proud': 244095,
#  'really': 244133,
#  'feelings': 243211,
#  'wife': 244211,
#  'whom': 224620,
#  'adore': 132903,
#  'miss': 239119,
#  'poland': 197468,
#  'show': 242068,
#  'because': 245031,
#  'surgery': 145878,
#  'name': 240555,
#  'bridget': 468,
#  'everything': 245052,
#  'jealous': 189070,
#  '#chatiado': 472,
#  'celebrate': 243527,
#  'every': 243990,
#  'played': 243933,
#  'fatherly': 180840,
#  'role': 242615,
#  'day#': 168478,
#  'sure': 240790,
#  'hour': 245092,
#  'white': 243371,
#  'establishment': 143475,
#  'folx': 45483,
#  'running': 215350,
#  'loving': 244416,
#  'themselves': 231081,
#  'promoting': 223267,
#  'greatness': 206744,
#  'journey': 231422,
#  'begins': 242984,
#  '#travel': 241240,
#  '#yeah': 203180,
#  '#thejourneybegins': 203181,
#  '#hello': 243902,
#  '#luv': 229194,
#  '#hottweets': 229195,
#  '#venusexchange': 229199,
#  'brochures': 510,
#  'arrived': 226074,
#  'exciting': 239379,
#  '#aworks': 129666,
#  '#solutions': 515,
#  'much': 244348,
#  'stuff': 236065,
#  'happening': 235168,
#  'florida': 238315,
#  'shooting': 244684,
#  '#disneygatorattack': 184663,
#  'ferrari': 68294,
#  'sake': 234495,
#  'championship': 221708,
#  'clearly': 242228,
#  'turning': 241836,
#  'point': 239013,
#  'mercs': 534,
#  'aced': 535,
#  'test': 233152,
#  'seeks': 236029,
#  'probe': 236030,
#  '#udtapunjab': 240265,
#  'leak': 236033,
#  'points': 236034,
#  'finger': 236035,
#  '#amarinder': 236036,
#  '#aap': 236037,
#  'wrapping': 69921,
#  '#senseaboutmaths': 43989,
#  'call': 244455,
#  '#race': 219017,
#  '#identity': 45119,
#  '#med': 557,
#  'might': 243588,
#  'shown': 222523,
#  'regurgitated': 564,
#  'calling': 244685,
#  'sometimes': 243745,
#  'raise': 215918,
#  'brows': 202373,
#  '#golfstrengthandconditioning': 574,
#  '#strong': 216950,
#  '#felixfoisgolf': 576,
#  '#greathonour': 57469,
#  '#careerconvos': 57470,
#  'designing': 220289,
#  '#innovative': 6363,
#  'learning': 216434,
#  'space': 237151,
#  'include': 585,
#  '#wateringhole': 586,
#  '#cave': 587,
#  '#mountaintop': 588,
#  '#campfire': 589,
#  '#altright': 206374,
#  'uses': 124270,
#  'insecurity': 22632,
#  'lure': 116662,
#  '#whitesupremacy': 244743,
#  'carrying': 237370,
#  'wouldn': 236178,
#  'helped': 194659,
#  'control': 239019,
#  'stop': 245195,
#  'black': 244509,
#  'market': 240931,
#  'terrorism': 244534,
#  'worse': 236451,
#  'power': 235917,
#  'mind': 243534,
#  '#heal': 215357,
#  'body': 242310,
#  '#altwaystoheal': 244026,
#  '#healthy': 244710,
#  'woohoo': 244913,
#  'over': 244391,
#  'weeks': 245236,
#  'place': 243764,
#  'where': 244553,
#  'family': 240439,
#  'members': 235467,
#  'rehearse': 629,
#  'music': 244643,
#  'videos': 244121,
#  'look': 243841,
#  'announcement': 233442,
#  '#midweek': 218252,
#  '#newmusic': 190201,
#  '#watchthisspace': 194685,
#  '#guitar': 231998,
#  'nights': 235412,
#  'channel': 239288,
#  'what': 245089,
#  'fuss': 166243,
#  'watching': 244942,
#  'episodes': 216929,
#  'offline': 214894,
#  'very': 244340,
#  'nice': 244578,
#  'long': 242843,
#  '#snapchat': 232450,
#  '#redhead': 202009,
#  '#vermillionred': 657,
#  'things': 245103,
#  'incredibly': 226262,
#  '#people': 242469,
#  'received': 241782,
#  'acceptance': 226688,
#  'letter': 235301,
#  'masters': 241286,
#  'back': 244785,
#  'october': 227888,
#  '#goodtimes': 225130,
#  '#history': 241817,
#  'daughter': 243533,
#  'riding': 170773,
#  'bike': 239860,
#  'driveway': 675,
#  'guitar': 215322,
#  'while': 240360,
#  'enjoy': 245081,
#  'campfire': 680,
#  '#summeime': 241509,
#  '#memories': 240746,
#  'station': 242312,
#  'done': 244629,
#  'course': 240623,
#  'always': 244830,
#  'hope': 243517,
#  'gonna': 236463,
#  'happen': 240606,
#  'anytime': 164714,
#  'soon': 244387,
#  'couple': 243997,
#  'naked': 243999,
#  'japanese': 240935,
#  'girls': 243375,
#  '#hump': 112837,
#  '#humpers': 715,
#  'edwardsville': 112842,
#  'pennsylvania': 717,
#  'personalised': 241016,
#  '#shop': 242282,
#  '#cool': 242283,
#  '#home': 242284,
#  '#fun': 244826,
#  'some': 244640,
#  'truly': 243128,
#  'sick': 244945,
#  'trump': 242830,
#  'obama': 240616,
#  'resign': 227529,
#  'orlando': 242106,
#  'shootings': 226374,
#  'years': 245244,
#  'talk': 245011,
#  'change': 242964,
#  '#nashvilletour': 742,
#  '#nashvilleforever': 743,
#  '#eur': 241561,
#  'clears': 110589,
#  'barrier': 160350,
#  'jumps': 238426,
#  'fresh': 238016,
#  'week': 245134,
#  'high': 244745,
#  'going': 244586,
#  'friends': 244986,
#  'still': 244111,
#  'wrap': 245251,
#  'head': 241659,
#  'fact': 238841,
#  'gone': 243494,
#  'destroyed': 243856,
#  'wait': 245241,
#  'baking': 227431,
#  '#eyelids': 780,
#  '#vigilfororlando': 783,
#  '#harp': 784,
#  '#clonakilty': 785,
#  '#rip': 243683,
#  '#ihavenofriends': 75558,
#  '#someonecomewithme': 75559,
#  '#relax': 243662,
#  '#icon': 236848,
#  '#woman': 244817,
#  '#sundaymorning': 215011,
#  '#sunday': 244991,
#  '#marilynmonroe': 796,
#  'interested': 237815,
#  '#linguistics': 798,
#  'doesn': 243925,
#  'address': 232668,
#  'racism': 244741,
#  '#power': 208681,
#  '#raciolinguistics': 806,
#  'brings': 242159,
#  'beloved': 202465,
#  'recovered': 193444,
#  'apple': 206398,
#  '#marvel': 233214,
#  '#song': 245191,
#  '#musica': 108892,
#  '#weed': 186064,
#  '#ripchristina': 243684,
#  '#adele': 148065,
#  '#dance': 237555,
#  'vine': 226826,
#  'mocked': 226857,
#  '#brexit': 232383,
#  '#under': 97326,
#  'spell': 103809,
#  'brexit': 237417,
#  'referendum': 242684,
#  'commerzbank': 188348,
#  'health': 244707,
#  'benefits': 244708,
#  'cucumbers': 244709,
#  '#ofw': 849,
#  '#pinoy': 233655,
#  '#followme': 244399,
#  '#igers': 241880,
#  '#instagood': 244314,
#  '#smile': 244977,
#  '#toradora': 856,
#  '#anime': 236095,
#  '#animeedit': 858,
#  '#breakups': 196722,
#  '#alone': 243462,
#  '#lonely': 245207,
#  'laps': 120425,
#  'pool': 207289,
#  'ride': 242288,
#  'picked': 239282,
#  'membership': 211499,
#  'form': 235989,
#  '#cotd': 133864,
#  'polar': 241179,
#  'bear': 241180,
#  'climb': 241177,
#  'racing': 241178,
#  'living': 241181,
#  'cold': 241182,
#  'places': 241183,
#  'looking': 244934,
#  'gets': 243069,
#  'muslim': 240405,
#  'assassinating': 5992,
#  'snappy': 892,
#  'waiting': 244610,
#  'football': 244256,
#  '#football': 242886,
#  'friday': 245143,
#  '#fringes#qcbags#summer': 899,
#  '#nochebuena': 138865,
#  '#lasvegas': 237229,
#  '#usa': 239025,
#  'vegas': 220993,
#  'strip': 186002,
#  'fleurette': 905,
#  '#instaboy#instaman#sefie#septum#friend': 906,
#  '#smiles#blackandwhite': 907,
#  'branches': 178308,
#  'rainy': 240040,
#  'writing': 239274,
#  'tears': 240302,
#  'flying': 245135,
#  'birds': 233120,
#  '#haiku': 192735,
#  'lines': 232174,
#  '#micropoetry': 128736,
#  'yeah': 243676,
#  'buttons': 37228,
#  'mail': 226454,
#  'pretty': 242065,
#  '#jewelrymaking': 923,
#  '#buttons': 161855,
#  'driver': 231079,
#  'female': 194534,
#  'moose': 172392,
#  'river': 234876,
#  '#weston': 929,
#  'killed': 242552,
#  'crews': 933,
#  'removing': 238818,
#  'animal': 235923,
#  'afterpas': 936,
#  'japan': 240235,
#  'madeinjapan': 939,
#  '#eos': 940,
#  'cute': 234943,
#  '#cawaii': 943,
#  '#strawberry': 239276,
#  '#tomato': 108937,
#  'aren': 242470,
#  'protesting': 242471,
#  '#trump': 244902,
#  '#republican': 242474,
#  'fuhered': 242478,
#  'find': 244036,
#  'spend': 240546,
#  '#boy': 235117,
#  '#guy': 220812,
#  'update': 244000,
#  '#social': 244001,
#  '#analytics': 244002,
#  '#photooftheday': 244463,
#  '#likes': 227655,
#  'anyone': 244952,
#  'date': 239635,
#  '#doj': 184183,
#  '#fbi': 184181,
#  'became': 216068,
#  'corrupted': 226874,
#  '#emailgate': 978,
#  '#hillary': 236059,
#  '#shameful': 244471,
#  '#disgraceful': 172654,
#  '#ridiculous': 244957,
#  '#stupidity': 220271,
#  'makes': 245178,
#  'than': 245235,
#  'even': 245150,
#  '#negligence': 238104,
#  '#sachintendulkar': 989,
#  'installation': 244849,
#  'thbihday': 134367,
#  '#bestfriend': 244606,
#  'most': 245114,
#  'impoant': 243204,
#  'thing': 244998,
#  '#enjoy': 244489,
#  'matters': 233065,
#  '#pooh': 1007,
#  'chris': 155315,
#  'evans': 191913,
#  'actor': 245111,
#  'human': 232207,
#  '#chrisevans': 133260,
#  'heas': 243723,
#  'thoughts': 243623,
#  'prayers': 243624,
#  'murdered': 229830,
#  '#florida': 242528,
#  'demoing': 1027,
#  'guitars': 1028,
#  'album': 242760,
#  '#newalbum': 1030,
#  '#indie': 233112,
#  '#guitars': 1032,
#  '#echobelly': 1033,
#  'retweeted': 220100,
#  'lion': 225765,
#  '#webmareting': 1037,
#  '#seo': 1038,
#  '#community': 229756,
#  '#management': 227327,
#  '#nzd': 227537,
#  'targets': 38881,
#  'worst': 243686,
#  'ever': 243094,
#  '#bihdayweeksucks': 146077,
#  '#bithday': 146078,
#  'blessed': 241156,
#  'worked': 240193,
#  'leading': 183937,
#  'ladies': 241891,
#  'happiest': 230142,
#  '#disneysmagickingdom': 1067,
#  '#disney': 238278,
#  '#magickingdom': 105568,
#  '#disneyland': 234954,
#  'kinda': 225603,
#  'among': 231986,
#  'humans': 234183,
#  'found': 243278,
#  'exclaiming': 1080,
#  'blain': 1081,
#  'hair': 244208,
#  'other': 244793,
#  'nite': 201082,
#  'listen': 241059,
#  'friend': 242722,
#  'voice': 242138,
#  'freedom': 243442,
#  'effo': 181474,
#  'present': 236879,
#  'merely': 230528,
#  'stored': 145203,
#  'past': 238911,
#  'theodore': 242261,
#  'roosevelt': 197428,
#  'yall': 235137,
#  'aint': 115322,
#  '#commitment': 1118,
#  '#trust': 232534,
#  '#faithful': 1120,
#  '#michelleobama': 219231,
#  'gorilla': 244079,
#  'racists': 241904,
#  'thought': 245004,
#  '#newarkfestival': 1132,
#  'internet': 227871,
#  'broken': 236716,
#  'watch': 244255,
#  'netflix': 209659,
#  '#mochithepug': 1145,
#  '#puglife': 81103,
#  'then': 245180,
#  'business': 244229,
#  'usual': 226082,
#  'dick': 214467,
#  'suckin': 96714,
#  'tequila': 96715,
#  'lovin': 113357,
#  'slut': 122965,
#  'wouldnt': 207740,
#  '#justalillate': 96721,
#  '#butstillontime': 96722,
#  'smaller': 175301,
#  'hands': 224897,
#  'barry': 147855,
#  'probably': 229076,
#  'lied': 197264,
#  '#knicks': 1173,
#  'game': 244794,
#  'sucked': 128256,
#  '#golf': 215658,
#  'everyone': 244990,
#  'doing': 244677,
#  '#goodmorning': 243761,
#  '#girls': 240325,
#  'challenges': 193549,
#  'claim': 235867,
#  '#punjabis': 133309,
#  '#drugaddicts': 133312,
#  'dares': 107661,
#  '#tracerequest': 1200,
#  'sending': 220584,
#  'deepest': 170680,
#  'condolences': 235576,
#  'zimbabwe': 19486,
#  'community': 243790,
#  '#touched': 1208,
#  'selfie': 241167,
#  '#mato': 1211,
#  '#chapones': 1212,
#  'saturday': 243948,
#  'afternoon': 245013,
#  'meet': 244579,
#  '#friends': 245028,
#  'soed': 241766,
#  'bolts': 1223,
#  '#bloke': 1224,
#  'bing': 243680,
#  'bong': 243681,
#  'dawned': 66474,
#  'months': 242804,
#  'seeing': 238854,
#  'live': 245095,
#  '#vfest': 1238,
#  '#summer': 245158,
#  'shane': 231415,
#  'robe': 216456,
#  'watson': 177758,
#  '#shane': 177760,
#  '#watson': 177761,
#  '#cricker': 177763,
#  'millions': 240547,
#  'pointed': 105294,
#  '#jewishsupremacist': 1256,
#  'hear': 245184,
#  'announcers': 3386,
#  'moved': 220418,
#  'player': 233328,
#  'lead': 224634,
#  '#whoknows': 1264,
#  '#radio': 201669,
#  '#coldplay': 159401,
#  'coming': 244584,
#  'through': 242378,
#  'keeping': 242427,
#  'terrorist': 239686,
#  'constitutional': 233161,
#  'rights': 235935,
#  'another': 244626,
#  'excuse': 244076,
#  'republicans': 243156,
#  'appease': 1283,
#  'measures': 170302,
#  '#gloucesterrugby': 1288,
#  'happened': 242567,
#  '#sad': 245001,
#  '#together': 239327,
#  '#down': 178978,
#  '#fine': 1298,
#  '#dandy': 1299,
#  '#exuberant': 1301,
#  '#depressed': 244109,
#  '#halffull': 1303,
#  '#halfempty': 1304,
#  '#mikeashley': 1305,
#  '#sposdirectshame': 1306,
#  'perhapse': 1307,
#  'example': 206484,
#  'protect': 242839,
#  '#workersrights': 1312,
#  'within': 239233,
#  'europe': 231424,
#  '#euref': 230916,
#  '#remain': 175390,
#  'stella': 174717,
#  'princess': 244603,
#  '#birds': 186949,
#  '#stella': 174721,
#  '#bad': 236447,
#  '#princess': 228686,
#  'birdsstellabadprincess': 1326,
#  'post': 241563,
#  'check': 244515,
#  'memories': 245026,
#  'said': 242716,
#  'cared': 234276,
#  '#really': 244138,
#  'hilarious': 191312,
#  'already': 240848,
#  'blocked': 242993,
#  'asking': 231861,
#  'paicularly': 234339,
#  'difficult': 238436,
#  'question': 204444,
#  'devastating': 167982,
#  'news': 241720,
#  'victims': 244692,
#  'happiness': 240156,
#  'state': 243120,
#  'arrive': 232107,
#  'manner': 206970,
#  'traveling': 244480,
#  'margaret': 70740,
#  '#runbeck': 1366,
#  '#happiness': 244600,
#  '#quotes': 243219,
#  '#inspirational': 243220,
#  'safe': 241890,
#  'ways': 243147,
#  'heal': 235228,
#  '#acne': 174051,
#  '#healing': 239531,
#  'creating': 239625,
#  '#beats': 244521,
#  '#makingbeats': 1382,
#  '#thursday': 240036,
#  '#istandard': 1385,
#  '#akaipro': 1386,
#  'wedding': 244020,
#  'number': 232606,
#  '#wedding': 244021,
#  '#weddingpay': 123764,
#  '#forever': 238694,
#  '#weddingdress': 193496,
#  'forward': 244935,
#  'attending': 227432,
#  'cipd': 200189,
#  'workshop': 224420,
#  '#cpd': 200192,
#  '#onemoreday': 1402,
#  'reached': 235725,
#  'followers': 244324,
#  '#twitch': 203487,
#  'follower': 206634,
#  ...}

# %%
import time
import sys
import numpy as np


class SarcasmNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        self.pre_process_data(reviews, labels)
      
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        self.review_vocab = list(review_vocab)
        

        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
  
        self.label_vocab = list(label_vocab)
        
     
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
     
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
    
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
  
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        self.learning_rate = learning_rate
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.hidden_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.layer_0 = np.zeros((1,input_nodes))
    
    def update_input_layer(self,review):

        self.layer_0 *= 0
        
        for word in review.split(" "):

            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 1):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):

        assert(len(training_reviews) == len(training_labels))


        start = time.time()

        for i in range(len(training_reviews)):
    
            review = training_reviews[i]
            label = training_labels[i]
   
            self.update_input_layer(review)

     
            layer_1 = self.layer_0.dot(self.weights_0_1)

        
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
     
            layer_2_error = layer_2 - self.get_target_for_label(label) 
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)


            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) 
            layer_1_delta = layer_1_error 
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate 
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate 


            
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5])
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):

        correct = 0

      
        start = time.time()

        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
        

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
       
       
        self.update_input_layer(review.lower())

        layer_1 = self.layer_0.dot(self.weights_0_1)

        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        
        if(layer_2[0] >= 0.5):
            return 1
        else:
            return 0

# %%
model_1 = SarcasmNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %%
model_1.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0
# Progress:8.07% Speed(reviews/sec):120.5
# Progress:16.1% Speed(reviews/sec):120.9
# Progress:24.2% Speed(reviews/sec):121.3
# Progress:32.2% Speed(reviews/sec):121.2
# Progress:40.3% Speed(reviews/sec):121.3
# Progress:48.4% Speed(reviews/sec):120.4
# Progress:56.5% Speed(reviews/sec):120.2
# Progress:64.5% Speed(reviews/sec):120.2
# Progress:72.6% Speed(reviews/sec):120.1
# Progress:80.7% Speed(reviews/sec):120.0
# Progress:88.8% Speed(reviews/sec):120.1
# Progress:96.8% Speed(reviews/sec):120.0
# Progress:99.9% Speed(reviews/sec):120.0

# %%
model_1.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:16.5% Speed(reviews/sec):999.9 #Correct:162 #Tested:166 Testing Accuracy:97.5%
# Progress:99.9% Speed(reviews/sec):1015. #Correct:951 #Tested:1000 Testing Accuracy:95.1%

# %%
import time
import sys
import numpy as np


class SarcasmNetworkNew:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
     
        self.pre_process_data(reviews, labels)
       
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
       
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

   
        self.review_vocab = list(review_vocab)
     
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
    
        self.label_vocab = list(label_vocab)
        
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
       
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
     
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

      
        self.learning_rate = learning_rate

        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

    
        self.weights_1_2 = np.random.normal(0.0, self.hidden_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    def get_target_for_label(self,label):
        if(label == 1):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
  
    def train(self, training_reviews_raw, training_labels):

    
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))

      
        assert(len(training_reviews) == len(training_labels))
   
        start = time.time()
   
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

          
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
          
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

       
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) 
            layer_1_delta = layer_1_error

        
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate 
            
         
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate 
                        
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5])
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
       
       
        correct = 0

        start = time.time()

        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
           
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] >= 0.5):
            return 1
        else:
            return 0

# %%
model_2 = SarcasmNetworkNew(reviews[:-1000],labels[:-1000], learning_rate=0.1)
model_2.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0
# Progress:6.56% Speed(reviews/sec):4747.
# Progress:8.07% Speed(reviews/sec):4132.
# Progress:10.0% Speed(reviews/sec):3894.
# Progress:12.8% Speed(reviews/sec):3963.
# Progress:15.3% Speed(reviews/sec):4045.
# Progress:16.1% Speed(reviews/sec):3980.
# Progress:20.5% Speed(reviews/sec):4099.
# Progress:22.1% Speed(reviews/sec):3936.
# Progress:24.2% Speed(reviews/sec):3937.
# Progress:27.3% Speed(reviews/sec):4001.
# Progress:29.9% Speed(reviews/sec):4013.
# Progress:32.2% Speed(reviews/sec):4051.
# Progress:35.4% Speed(reviews/sec):4100.
# Progress:37.9% Speed(reviews/sec):4089.
# Progress:40.3% Speed(reviews/sec):4099.
# Progress:43.6% Speed(reviews/sec):4150.
# Progress:46.3% Speed(reviews/sec):4153.
# Progress:48.4% Speed(reviews/sec):4163.
# Progress:51.4% Speed(reviews/sec):4174.
# Progress:54.0% Speed(reviews/sec):4165.
# Progress:56.5% Speed(reviews/sec):4172.
# Progress:59.4% Speed(reviews/sec):4196.
# Progress:61.8% Speed(reviews/sec):4196.
# Progress:64.5% Speed(reviews/sec):4214.
# Progress:67.3% Speed(reviews/sec):4217.
# Progress:69.8% Speed(reviews/sec):4214.
# Progress:72.6% Speed(reviews/sec):4225.
# Progress:72.6% Speed(reviews/sec):4223.
# Progress:78.0% Speed(reviews/sec):4243.
# Progress:79.6% Speed(reviews/sec):4191.
# Progress:80.7% Speed(reviews/sec):4191.
# Progress:85.1% Speed(reviews/sec):4213.
# Progress:87.1% Speed(reviews/sec):4186.
# Progress:88.8% Speed(reviews/sec):4188.
# Progress:92.5% Speed(reviews/sec):4201.
# Progress:94.6% Speed(reviews/sec):4185.
# Progress:96.8% Speed(reviews/sec):4189.
# Progress:99.9% Speed(reviews/sec):4199.

# %%
model_2.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:89.2% Speed(reviews/sec):5068. #Correct:850 #Tested:893 Testing Accuracy:95.1%
# Progress:99.9% Speed(reviews/sec):5285. #Correct:948 #Tested:1000 Testing Accuracy:94.8%
